# %% [raw]
# ---
# toc: true
# layout: post
# title: Adventure Game Documentation
# description: Shows the journy of creating the quest system for an adventure game.
# menu: nav/quests.html
# permalink: adventuregame/documentation
# ---

# %% [markdown]
# [Issue](https://github.com/mrboiisthebest/william_2025/issues/16)
#
# In the link above is the temporary place for the documentation

# %% [markdown]
# [IDEAS BLOG](http://127.0.0.1:4100/william_2025/adventuregame/ideas)
# [Game](https://mrboiisthebest.github.io/william_2025/gamify/adventureGame)
#
# ### Road map
#
# Quests
# - [x] Add quests skeleton (add how quests will work and function) [1/31/25]
# - [x] Finish quest function system (progress in quests, types of quests, and complete quests) [2/6/25
#        -  allow more than 1 quest to work at a time
#        -  allow progression through quest
#        -  add a way to finish quests
# - [x] optimize current quest system and fix small bugs [2/6/25]
#        -  make the quest load when the level loads so every level does not have there quest active at once
# - [x] Add a npc for quests npc [2/7/25]
#        - inside of the level add the npc data
#        - place npc on the right of the screen
#        - Make a questNpc.js to fully customize the quest npc as the current npc.js file is focused on quizzes
# - [x] Make the npc give quests to the player
#        - when colliding with the npc make 1 random quest be added to the quest list
#        - add a delay after getting another quest
#        - when the quest gets completed when going back to the npc the quest will be removed from the quest list
# - [x] Add ui for quests
#        - add the skeleton of how the dialogue will be made / shown
#        - make a small box show up with text inside
#        - make the box show the quest name
#        - add a quest description value
#        - show description  in the box
#        - Make a function inside of quest system that handles the ui
#
# - [x] add dialogue
# - [x] Spawn item on map when getting the scavenger quest
#       - Make the spawn function inside of questSystem.js
#       - Select a random Spot on the level (decided to go with set pos)
#       - Spawn a sprite
#       - Add spire data
#       - base sprite data off of the selected item
# - [x] Make the scavenger hunt pick a random item
#       - Select random item in an array of all items
#       -  Assign item to the quest
# - [x] Add more Collectibles
#       -  Add a flower
#       -  Add a Hammer
#       -  Add a broken plate
#
#
#
# IF leftover time
# create a system that auto generates random quests for the current level to make inf quests
#
# Player
# - [ ] Make movement accelerate start faster
# - [ ] increase movement speed
#
#
# Reminders
# Look at slack and follow the stuff
#
# How to document
#
# Use drawio to describe how every step works, How a quest is given(duolog, what the quest is etc),How quests are made, layout how to make the quests so after you finish 1 section you can move to the next like a list on drawio, just explain in more detail and show how you are going to do it before you do it.
#
# As of 2/4/25 there will be sub goals that will be like the checklist but on how to to the next goal or progress in it
#
# 1/30/25
#
# I have added 2 js files QuestSystem.js and Quests.js
#
# In the image below you can see where the quests are being stored
#
# ![Image](https://github.com/user-attachments/assets/6f1d99b9-d855-471a-b089-b5cde856f2fb)
#
# In the image below it shows how the quests are being created and added into the Quest System
#
# ![Image](https://github.com/user-attachments/assets/9bf4f090-1b61-4633-8a48-518af1951730)
#
# In the adventureGame.md I have sectioned out a place for the scripts and where the future UI might be
#
# ![Image](https://github.com/user-attachments/assets/8d2c9825-fc3c-4b3a-9f75-0ee68afbc1b2)
#
# Inside of the levels you can add quests which will be very customizable with different types of quests
#
# ![Image](https://github.com/user-attachments/assets/f5f4f8c6-9113-419a-b4ea-0d433baefa29)

# %% [markdown]
# 1/31/25
#
# I have added 2 types of quest a scavenger and a talk to npc quests.
#
# ![Image](https://github.com/user-attachments/assets/1f29a210-a134-4b3d-aa1e-56bfa6575ebf)
#
# The quests values are stored in an array for future use on tracking how far you have progressed on the quest
#
# How I will update quest progress with actions inside the game
#
# ![Image](https://github.com/user-attachments/assets/9d8d1d3d-b867-4db1-a0b1-893392ed204f)
#
# This is were the npc  collider checks are for when they talk to you
# ![Image](https://github.com/user-attachments/assets/c1548533-0816-43c9-8d15-e9196761839b)

# %% [markdown]
# 2/3/25
#
# Instead of the previous way of checking if you collided with an npc, obj etc. I was going to but multiple lines of code sending checks, but instead of have checks in a bunch of places I decided to place the checks in the collision system to send checks whenever there is a player collision.
#
# ![Image](https://github.com/user-attachments/assets/68547860-2ec7-460d-90c9-e85f2805938e)

# %% [markdown]
# 2/4/25
#
# I added logic to check when a quest has been progressed in and removed the quest check functions for the scavenger and npc quest as when they were called they were not created in time.
#
# ![Image](https://github.com/user-attachments/assets/af6166a7-7d2f-458e-8e5e-7356e7739c65)
#
# <img width="284" alt="Image" src="https://github.com/user-attachments/assets/66484cf2-7a8c-415a-a8d3-0e8375b953f1" />
#
# Plans for next changes
#
#
# Sub Goal
# the next set of changes want to add is that the quests values will be updated after talking to an npc then fully implement the scavenger quest.

# %% [markdown]
# 2/5/25
#
# I have decided to move the quest checks inside of the quest update function inside of Quests.js to organize were the quests function are in. For the npc quest the code removes the npc if it found on the npc list and if the list has nothing inside of it it will render the quest as completed.
#
# ![Image](https://github.com/user-attachments/assets/4d27002b-0081-46e8-9bb4-2330c44560a1)
#
# Now inside if QuestSystem.js I made it so when colliding with objects inside of the level it will find what kind of level corresponds to the object and trigger the function to update the quest
#
# ![Image](https://github.com/user-attachments/assets/6bb10d5f-3885-4f20-b676-beb8c88f01fa)
# (these images show changes for the npc quest)
#
#
# sub goal
#
# Finish the scavenger quest progression and complition

# %% [markdown]
# 2/6/25
#
#
# In the image below you can see that I changed to a class system and I have a function that creates a new quest object.
#
# ![Image](https://github.com/user-attachments/assets/c74c6aee-e718-452c-844e-cc41fa8a9164)
#
# In the image below is were Levels will store there quests then it will add the quests to current levels
#
# ![Image](https://github.com/user-attachments/assets/20e20409-c897-4fd6-9333-7117d6f80ffa)
#
# in the image below you can see how the quest upd function works which will upd quest values based on what  type of quest it is
# ![Image](https://github.com/user-attachments/assets/4b8e4390-9603-40b2-8ba8-70dbc300dd34)
#
# Now when the level gets loaded the corresponding levels will also laod
#
# ![Image](https://github.com/user-attachments/assets/b7916758-d4d3-4687-8944-0abae295fe27)
#
# Next Goal
#
# add the npc

# %% [markdown]
# 2/7/25
#
# In the bottom 2 images it shows how I added the new Activated value into the quest object. When this value is false the quest will be ignored when running quest checks meaning quest can only be progressed through when they have been activated.
# In the final 2 images It shows how I added the new quest NPC. When interacting with this npc it will chose 1 random quest and turn its activated value to true.
#
# ![Image](https://github.com/user-attachments/assets/fc6d1c5d-5c83-4e7f-be76-48690fdc9c1e)
#
# ![Image](https://github.com/user-attachments/assets/e4cf25db-267f-47c0-822a-905c4f95ab7b)
#
# ![Image](https://github.com/user-attachments/assets/ae7313d1-19a2-49ff-9bb3-db889daf32fe)
#
# ![Image](https://github.com/user-attachments/assets/82468b23-b289-4378-b36e-945cfd5332f8)
#
# Sub Goal
#
# Before he quest npc gives you a random quest it will check if the quest has been completed as I only want quests to be completed once.

# %% [markdown]
# 2/10/25
#
#
# In the images below it shows the function that are used to find the random quest that will be assigned to the player when interacting with the quest npc. When finding the random quest it needs to have a list of all non completed or assigned quest so it can quickly assign quest that are ready to be done
#
# ![Image](https://github.com/user-attachments/assets/446b6de4-53f3-4d2b-8e39-046631fa22e6)
#
# ![Image](https://github.com/user-attachments/assets/0c873ef0-f509-4385-a75c-fb5277c38473)
#
# Added a div into the MD file for the quest messages to show in
#
# ![Image](https://github.com/user-attachments/assets/8486fd9e-3f75-4226-827b-a8e64f3dcbe0)
#
#
# Sub Goal
#
# Create a displayMessage(message) function in QuestSystem.js to allow updates or dialogue to be given to the player

# %% [markdown]
# 2/11/25 & 2/12/25
#
# Bugs
#
# - can interact with quest npc from any were
#
# To fix the bug were you can interact with the quest npc from anywhere I had to add a function that uses the built in collision system to detect if the player is touching the npc. If it is a random quest will be given with a message output
#
# ![Image](https://github.com/user-attachments/assets/381600c6-133a-4bcb-ba43-fb426a0c13f8)
#
# ![Image](https://github.com/user-attachments/assets/0c26b1d2-3975-4886-a5a6-ce7b9517c167)
#
# The images below show different outputs that the quest message box can have
#
# ![Image](https://github.com/user-attachments/assets/678c2497-40f0-48fc-b771-cfbe86f999b0)
# ![Image](https://github.com/user-attachments/assets/adbd1bb2-26af-4dbf-a998-871084b9bfbf)
# ![Image](https://github.com/user-attachments/assets/f1d27673-85af-44d2-a9ac-915747b5ceac)
#
# there are many images of code I am not putting on how the messages work as they will take up way to much room in this issue the future blog will be more detailed
#
# Next Goal
#
# As of now everything is working for the npc quest so my next goal is to get the scavenger quest to work and implement a scavenger object onto the canvas

# %% [markdown]
# 2/13/25
#
# I added a new ScavengerObject class for the scavenger quest. As of now the object must be placed onto the screen when the game loads and not when the quest is given
# ![Image](https://github.com/user-attachments/assets/16469c9f-3633-4d8b-bc62-6c8ebe04c558)
#
# ![Image](https://github.com/user-attachments/assets/0acd5307-190e-4dab-9c2c-318eb6fd7d67)
#
# When the player is assigned a scavenger quest the object appears on the screen
# ![Image](https://github.com/user-attachments/assets/4c174913-40f0-477e-9c75-463156da351c)
#
# next goal.
# Make an array of objects that can be randomly selected from

# %% [markdown]
# 2/14/25
#
# The image below is an example of what the scavenger quest objects will look like
# ![Image](https://github.com/user-attachments/assets/06073533-9183-4d32-a4f8-8cf2c8877d91)
# I added quests to gameleveldessert as I am done testing
# ![Image](https://github.com/user-attachments/assets/e877ad77-befe-49e6-a95b-689ae1008057)
#
# The code below is a switch statement in which when it is given an id the corresponding object will be created and placed into the game
# ![Image](https://github.com/user-attachments/assets/a033dc41-55cc-490b-834c-a9ea6acc09d8)
#
# Next Step.
# Create blogs to organize how everything works and store all info inside of this issue
